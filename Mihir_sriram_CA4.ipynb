# %% [markdown]
# # B-Tree
#
# B-tree is a common data structure for managing data stored in hard disks. Because of the mechanincal movements of hard disks (arm moving and disk spining), it is most economical to bring a large chunk of data stored consecutively into the main memory in one disk-read operation and write a large chunkof data to a disk in one disk-read operation. This chunk of data is called a page. The size of one page ranges from $2^{11} = 2,048$ bytes to $2^{14} = 16,384$ bytes. B-tree stores one page of data in one node. To facilitate searching, each internal node can hold multiple keys. To cut down disk accesses, we want a B-tree to be short.
#
# <img src="Disk.png" width="300"/>
#
# The typical pattern for working with an object is as follows:
#
# $x$ is a pointer to some object
# DISK-READ($x$)
# operations that access and/or modify the attributes of $x$
# DISK-WRITE($x$) (omitted if no attributes of x were changed)
# other operations that access but do not modify attributes of $x$
#
# In a B-tree, as in any form of BST, any "satellite information” (data) associated with a key resides in the same node as the key. Or we may think of a key as a point to the data.
#
# In a variant of B-tree called B$^+$-tree, all the satellite information (data) is stored in the leaves and the internal nodes only store keys and child pointers. This maximizes the branching factor of the internal nodes.

# %% [markdown]
# ## B-tree definition
#
# A tree $T$ is a B-tree if it satisfies the following conditions:
#
# 1. All leaves are at the same level.
# 2. Let $t\geq 2$ be a positive integer called a minimum degree, whose value is determined by the page size.
# 3. Every node except the root must contain at least $t-1$ keys. If $T$ is not empty, then the root contains one or more keys.
# 4. All nodes (the root included) may contain upto $2t – 1$ keys. A node is full if it contains exactly $2t-1$ keys.
# 5. Each internal node of $k$ keys has $k+1$ children. Thus, an internal node may have at most $2t$ children.
# 6. Keys of a node are sorted in increasing order. The child between two keys $k_1$ and $k_2$ contains all keys in the range between $k_1$ and $k_2$.
#
#
# The following is an example of 2-3-4 B-tree, i.e., each node has 2, 3, or 4 children:
#
# <img src="Fig18-1.png" width="600"/>

# %% [markdown]
# ## Properties
#
# 1. B-Tree grows and shrinks from the root. This is different from BST, which grows downward and shrinks upward.
# 2. Inserting a new node in B-tree happens only at the leave level.
# 3. Like other balanced BST such as AVL and red-black trees, each operation of search, insert, and delete incurs $O(\log_t n) = O(\log n)$ disk accesses (see below), since the minimum degree $t$ is a constant.
#
# Let $h$ be the height of a B-tree $T$ with a minimum degree $t$. Let $n$ be the total number of keys in $T$. Then
# $$h \leq \log_t \frac{n+1}{2}.$$
#
# Proof.
# \begin{align*}
# n \geq 1 + (2t + 2t^2 + \cdots + 2t^{h-1})(t-1) = 1 + \frac{2(t^h - 1)}{t-1}(t-1) = 2t^h -1.
# \end{align*}

# %% [markdown]
# ## Applications of B-Trees
#
# 1. Searching for data in a dataset stored on a hard disk can be achieved in significantly less time using the B-Tree
# 2. Most servers use the B-tree to manage data.
# 3. B-Trees are used in natural language processing, computer networks, and cryptography, among others.

# %% [markdown]
# ## B-tree search and insertion
#
# 1. Without loss of generality, assume that the root of the B-tree is always in main memory, so that no disk-read on the root is needed. We only need to perform a disk-write of the root whenever the root node is changed.
#
# 2. Any nodes that are passed as parameters must already have had a disk-read operation performed on them.
#
# 3. Inserting a new key to a full root causes the root to split to a new root, and hence the height of the tree is incremented by 1. This is different from BST insertion.
#
# <img src="Split.png" width="600"/>
#
# <img src="Insertion.png" width="600"/>

# %%
# Create a node
class BTreeNode:
    def __init__(self, leaf=False):
        self.leaf = leaf
        self.keys = []
        self.child = []
        
# BTree
class BTree:
    def __init__(self, t): # t is the minimum degree
        self.root = BTreeNode(True)
        self.t = t

    # Search key k starting from x
    # If x is not specified, search k starting from the root
    def search_key(self, k, x=None, disk_accesses=0):
        
        if x is None:
            return self.search_key(k, self.root, disk_accesses)
        else: # x is a current node
            disk_accesses += 1
            i = 0
        while i < len(x.keys) and k > x.keys[i][0]:
            i += 1
        if i < len(x.keys) and k == x.keys[i][0]:
            
            return (x, i, disk_accesses-1) # found k
        elif x.leaf: # if k is not in x and x has no children
            return None
        else:
            disk_accesses+=1
            return self.search_key(k, x.child[i],disk_accesses-1)
               
    # Insert key k, which is in th form of a pair key and content
    def insert(self, k):
        root = self.root
        if len(root.keys) == 2 * self.t - 1: # full--no keys are available
            temp = BTreeNode()
            self.root = temp
            temp.child.insert(0, root) 
            #list insert: at location 0, insert root; that is, temp points to root
            self.split_child(temp, 0)
            self.insert_non_full(temp, k)
        else:
            self.insert_non_full(root, k)
            
    # Split the child x at location i
    def split_child(self, x, i): 
        t = self.t # minimum degree
        y = x.child[i]
        z = BTreeNode(y.leaf)
        x.child.insert(i + 1, z) # list insert
        x.keys.insert(i, y.keys[t - 1])
        z.keys = y.keys[t: (2 * t) - 1]
        y.keys = y.keys[0: t - 1]
        if not y.leaf:
            z.child = y.child[t: 2 * t]
            y.child = y.child[0: t - 1]

    # Insert nonfull
    def insert_non_full(self, x, k):
        i = len(x.keys) - 1
        if x.leaf:
            x.keys.append((None, None)) # add a new key pair holder (None, None)
            while i >= 0 and k[0] < x.keys[i][0]:
                x.keys[i + 1] = x.keys[i]
                i -= 1
            x.keys[i + 1] = k # insert k
        else:
            while i >= 0 and k[0] < x.keys[i][0]:
                i -= 1
            i += 1
            if len(x.child[i].keys) == (2 * self.t) - 1:
                self.split_child(x, i)
                if k[0] > x.keys[i][0]:
                    i += 1
            self.insert_non_full(x.child[i], k)

    # Print the tree
    def print_tree(self, x, l=0):
        print("Level ", l, " ", len(x.keys), end=":")
        for i in x.keys:
            print(i, end=" ")
        print()
        l += 1
        if len(x.child) > 0:
            for i in x.child:
                self.print_tree(i, l)

# %%
# driver code

B = BTree(3) # t = 3
    
for i in range(150):
    B.insert((i,10 + 2 * i))

B.print_tree(B.root)



if B.search_key(107) is not None:
    print("\nFound")
    print(B.search_key(107)[2])
else:
    print("\nNot Found")

if B.search_key(82) is not None:
    print("\nFound")
    print(B.search_key(82)[2])
else:
    print("\nNot Found")
# Out:
# Level  0   4:(26, 62) (53, 116) (80, 170) (107, 224)
# Level  1   2:(8, 26) (17, 44)
# Level  2   2:(2, 14) (5, 20)
# Level  3   2:(0, 10) (1, 12)
# Level  3   2:(3, 16) (4, 18)
# Level  2   2:(11, 32) (14, 38)
# Level  3   2:(9, 28) (10, 30)
# Level  3   2:(12, 34) (13, 36)
# Level  1   2:(35, 80) (44, 98)
# Level  2   2:(29, 68) (32, 74)
# Level  3   2:(27, 64) (28, 66)
# Level  3   2:(30, 70) (31, 72)
# Level  2   2:(38, 86) (41, 92)
# Level  3   2:(36, 82) (37, 84)
# Level  3   2:(39, 88) (40, 90)
# Level  1   2:(62, 134) (71, 152)
# Level  2   2:(56, 122) (59, 128)
# Level  3   2:(54, 118) (55, 120)
# Level  3   2:(57, 124) (58, 126)
# Level  2   2:(65, 140) (68, 146)
# Level  3   2:(63, 136) (64, 138)
# Level  3   2:(66, 142) (67, 144)
# Level  1   2:(89, 188) (98, 206)
# Level  2   2:(83, 176) (86, 182)
# Level  3   2:(81, 172) (82, 174)
# Level  3   2:(84, 178) (85, 180)
# Level  2   2:(92, 194) (95, 200)
# Level  3   2:(90, 190) (91, 192)
# Level  3   2:(93, 196) (94, 198)
# Level  1   3:(116, 242) (125, 260) (134, 278)
# Level  2   2:(110, 230) (113, 236)
# Level  3   2:(108, 226) (109, 228)
# Level  3   2:(111, 232) (112, 234)
# Level  2   2:(119, 248) (122, 254)
# Level  3   2:(117, 244) (118, 246)
# Level  3   2:(120, 250) (121, 252)
# Level  2   2:(128, 266) (131, 272)
# Level  3   2:(126, 262) (127, 264)
# Level  3   2:(129, 268) (130, 270)
# Level  2   4:(137, 284) (140, 290) (143, 296) (146, 302)
# Level  3   2:(135, 280) (136, 282)
# Level  3   2:(138, 286) (139, 288)
# Level  3   2:(141, 292) (142, 294)
# Level  3   2:(144, 298) (145, 300)
# Level  3   3:(147, 304) (148, 306) (149, 308)
#
# Found
# 0
#
# Found
# 3

# %% [markdown]
# ## Delete a key from a B-tree
#
# Deleting a key from a B-tree consists of three main events:
# 1. Determine by searching if a node that contains the key to be deleted exists.
# 2. Delete the key from the node that contains it.
# 3. Balance the tree if needed.
#
# B-tree deletion is more complex than red-black tree deletion.
#
# Underflow occurs when a node contains less than the minimum number of keys it should hold.
#
# Two terminologies:
# 1. Inorder Predecessor of a node is the largest key on the left child of the node.
# 2. Inorder Successor of a node is the smallest key on the right child of the node.

# %% [markdown]
# ### Case I: The key to be deleted is in the leaf. There are two sub-cases:
#
# <b>I-1</b>: The node containing the key to be deleted has more than $t-1$ keys. Thus, deleting the key is straightforward, for it does not violate the property of the minimum number of keys a node should hold. In the tree below, deleting 32 does not violate the above properties, where $t = 2$.
#
# <img src="delete-leaf-1.webp" width="450"/>

# %% [markdown]
# <b>I-2</b>: The node containing the key to be deleted has $t - 1$ keys. Thus, deleting the key violates the property of the minimum number of keys a node should hold.
#
# To maintain the property of B-tree, we first check if its immediate left sibling has at least $t$ keys, if so, borrow a key from it. If not, check if its immediate right sibling
# has at least $t$ keys, if so, borrow a key from it.
#
# In the tree below, deleting 31 yields a violation, and a key from the left sibling can be borrowed.
#
# <img src="delete-leaf-2.webp" width="450"/>

# %% [markdown]
# If both the immediate sibling nodes have $t-1$ keys, then merge the node with either the left sibling node or the right sibling node. This merging is done through the parent node.
#
# <img src="delete-leaf-3.webp" width="450"/>

# %% [markdown]
# ### Case II: The key to be deleted is in an internal node
#
# <b>II-1</b>: The internal node containing the key to be deleted is replaced by an inorder predecessor if the key's left child has more than $t-1$ keys.
#
# <img src="delete-internal-1.webp" width="450"/>

# %% [markdown]
# <b>II-2</b> The internal node containing the key to be deleted, is replaced by an inorder successor if the right child of the key has more than $t-1$ keys. This similar to case II.1.
#
# <b>II-3</b> Both children of the key have exactly $t-1$ keys, then merge the left and the right children.
#
# <img src="delete-internal-2.webp" width="450"/>
#
# After merging, if the parent node has less than $t-1$ keys, then look for its siblings as in Case I.

# %% [markdown]
# ### Case III:  The height of the tree is reduced
#
# If the target key is in an internal node, and the deletion of the key leads to less than $t-1$ nodes, then look for the key's left child (inorder predecessor) and the key's right child (inorder successor). If both children contain $t-1$ keys, then merge the children as in Case II-3.
#
# Again, look for the sibling to borrow a key. But, if the sibling also has only $t-1$ keys, then merge the node with the sibling along with the parent. Arrange the children accordingly (increasing order).
#
# <img src="delete-internal_3.webp" width="450"/>

# %%
# Delete a node
def delete(self, x, k):
    t = self.t
    i = 0
    while i < len(x.keys) and k[0] > x.keys[i][0]:
        i += 1
    if x.leaf:
        if i < len(x.keys) and x.keys[i][0] == k[0]:
            x.keys.pop(i)
            return
        return

    if i < len(x.keys) and x.keys[i][0] == k[0]:
        return self.delete_internal_node(x, k, i)
    elif len(x.child[i].keys) >= t:
        self.delete(x.child[i], k)
    else:
        if i != 0 and i + 2 < len(x.child):
            if len(x.child[i - 1].keys) >= t:
                self.delete_sibling(x, i, i - 1)
            elif len(x.child[i + 1].keys) >= t:
                self.delete_sibling(x, i, i + 1)
            else:
                self.delete_merge(x, i, i + 1)
        elif i == 0:
            if len(x.child[i + 1].keys) >= t:
                self.delete_sibling(x, i, i + 1)
            else:
                self.delete_merge(x, i, i + 1)
        elif i + 1 == len(x.child):
            if len(x.child[i - 1].keys) >= t:
                self.delete_sibling(x, i, i - 1)
            else:
                self.delete_merge(x, i, i - 1)
        self.delete(x.child[i], k)

setattr(BTree, 'delete', delete)

# %%
# Delete internal node
def delete_internal_node(self, x, k, i):
    t = self.t
    if x.leaf:
        if x.keys[i][0] == k[0]:
            x.keys.pop(i)
            return
        return

    if len(x.child[i].keys) >= t:
        x.keys[i] = self.delete_predecessor(x.child[i])
        return
    elif len(x.child[i + 1].keys) >= t:
        x.keys[i] = self.delete_successor(x.child[i + 1])
        return
    else:
        self.delete_merge(x, i, i + 1)
        self.delete_internal_node(x.child[i], k, self.t - 1)

setattr(BTree, "delete_internal_node", delete_internal_node)

# %%
# Delete the predecessor
def delete_predecessor(self, x):
    if x.leaf:
        return x.pop()
    n = len(x.keys) - 1
    if len(x.child[n].keys) >= self.t:
        self.delete_sibling(x, n + 1, n)
    else:
        self.delete_merge(x, n, n + 1)
    self.delete_predecessor(x.child[n])

setattr(BTree, "delete_predecessor", delete_predecessor)

# %%
# Delete the successor
def delete_successor(self, x):
    if x.leaf:
        return x.keys.pop(0)
    if len(x.child[1].keys) >= self.t:
        self.delete_sibling(x, 0, 1)
    else:
        self.delete_merge(x, 0, 1)
    self.delete_successor(x.child[0])

setattr(BTree, "delete_successor", delete_successor)

# %%
# Delete resolution
def delete_merge(self, x, i, j):
    cnode = x.child[i]

    if j > i:
        rsnode = x.child[j]
        cnode.keys.append(x.keys[i])
        for k in range(len(rsnode.keys)):
            cnode.keys.append(rsnode.keys[k])
            if len(rsnode.child) > 0:
                cnode.child.append(rsnode.child[k])
        if len(rsnode.child) > 0:
            cnode.child.append(rsnode.child.pop())
        new = cnode
        x.keys.pop(i)
        x.child.pop(j)
    else:
        lsnode = x.child[j]
        lsnode.keys.append(x.keys[j])
        for i in range(len(cnode.keys)):
            lsnode.keys.append(cnode.keys[i])
            if len(lsnode.child) > 0:
                lsnode.child.append(cnode.child[i])
        if len(lsnode.child) > 0:
            lsnode.child.append(cnode.child.pop())
        new = lsnode
        x.keys.pop(j)
        x.child.pop(i)

    if x == self.root and len(x.keys) == 0:
        self.root = new

setattr(BTree, "delete_merge", delete_merge)

# %%
# Delete the sibling
def delete_sibling(self, x, i, j):
    cnode = x.child[i]
    if i < j:
        rsnode = x.child[j]
        cnode.keys.append(x.keys[i])
        x.keys[i] = rsnode.keys[0]
        if len(rsnode.child) > 0:
            cnode.child.append(rsnode.child[0])
            rsnode.child.pop(0)
        rsnode.keys.pop(0)
    else:
        lsnode = x.child[j]
        cnode.keys.insert(0, x.keys[i - 1])
        x.keys[i - 1] = lsnode.keys.pop()
        if len(lsnode.child) > 0:
            cnode.child.insert(0, lsnode.child.pop())

setattr(BTree, "delete_sibling", delete_sibling)

# %%
# driver code
B.delete(B.root, (8,))
B.print_tree(B.root)
# Out:
# Level  0   3:(53, 116) (80, 170) (107, 224)
# Level  1   4:(17, 44) (26, 62) (35, 80) (44, 98)
# Level  2   4:(2, 14) (5, 20) (11, 32) (14, 38)
# Level  3   2:(0, 10) (1, 12)
# Level  3   2:(3, 16) (4, 18)
# Level  3   4:(9, 28) (10, 30) (12, 34) (13, 36)
# Level  3   2:(12, 34) (13, 36)
# Level  2   2:(29, 68) (32, 74)
# Level  3   2:(27, 64) (28, 66)
# Level  3   2:(30, 70) (31, 72)
# Level  2   2:(38, 86) (41, 92)
# Level  3   2:(36, 82) (37, 84)
# Level  3   2:(39, 88) (40, 90)
# Level  2   2:(38, 86) (41, 92)
# Level  3   2:(36, 82) (37, 84)
# Level  3   2:(39, 88) (40, 90)
# Level  1   2:(62, 134) (71, 152)
# Level  2   2:(56, 122) (59, 128)
# Level  3   2:(54, 118) (55, 120)
# Level  3   2:(57, 124) (58, 126)
# Level  2   2:(65, 140) (68, 146)
# Level  3   2:(63, 136) (64, 138)
# Level  3   2:(66, 142) (67, 144)
# Level  1   2:(89, 188) (98, 206)
# Level  2   2:(83, 176) (86, 182)
# Level  3   2:(81, 172) (82, 174)
# Level  3   2:(84, 178) (85, 180)
# Level  2   2:(92, 194) (95, 200)
# Level  3   2:(90, 190) (91, 192)
# Level  3   2:(93, 196) (94, 198)
# Level  1   3:(116, 242) (125, 260) (134, 278)
# Level  2   2:(110, 230) (113, 236)
# Level  3   2:(108, 226) (109, 228)
# Level  3   2:(111, 232) (112, 234)
# Level  2   2:(119, 248) (122, 254)
# Level  3   2:(117, 244) (118, 246)
# Level  3   2:(120, 250) (121, 252)
# Level  2   2:(128, 266) (131, 272)
# Level  3   2:(126, 262) (127, 264)
# Level  3   2:(129, 268) (130, 270)
# Level  2   4:(137, 284) (140, 290) (143, 296) (146, 302)
# Level  3   2:(135, 280) (136, 282)
# Level  3   2:(138, 286) (139, 288)
# Level  3   2:(141, 292) (142, 294)
# Level  3   2:(144, 298) (145, 300)
# Level  3   3:(147, 304) (148, 306) (149, 308)

# %%
import numpy as np
from random import *
for j in range(0,10):
    print('\t---------------- This is Round: ',j ,'-------------------')
    key_list = [k + 1 for k in np.random.permutation(100_000)]
    B = BTree(512)
    l=len(key_list)
    find=[]
    for p in range(100):
        x=randint(1,100000)

        find.append(x)


    for i in range (l):
        B.insert((i,key_list[i]))
    '''B.print_tree(B.root)'''
    a=0


    for o in range (100):
        y=find[o]
        print(y)
        if B.search_key(y) is not None:
            print("\n Found")
            print("\n \n \n The number of disk access used to find the key is",B.search_key(y)[2])
            a=a+B.search_key(y)[2]
        else:
            print("\nNot Found")
    print('\n ---------------Number of total disk acceses: ',a,'---------------------')
# Out:
# 	---------------- This is Round:  0 -------------------
# 16301
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 32589
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 50863
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 63876
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 91255
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 85943
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 74269
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 96755
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 69463
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 23859
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 82947
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 33115
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 44027
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 14061
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 98966
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 50328
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 9900
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 26973
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 74079
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 52236
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 91819
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 93421
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 9579
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 91714
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 20256
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 8765
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 94367
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 55255
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 4162
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 57346
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 55705
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 94864
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 19268
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 94577
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 16312
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 71320
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 64584
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 79830
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 44339
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 81989
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 89219
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 63516
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 74663
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 93250
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 54766
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 19687
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 47934
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 36402
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 39181
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 79579
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 93936
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 83874
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 57195
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 11605
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 73350
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 77365
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 3822
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 31572
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 89031
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 86313
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 57018
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 11282
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 60010
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 72636
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 26600
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 34045
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 53719
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 56332
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 44708
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 13366
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 53217
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 37326
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 82559
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 36659
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 85449
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 52186
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 50340
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 29818
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 92140
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 82356
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 33553
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 27814
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 50867
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 53790
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 45010
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 6355
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 68568
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 62626
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 43419
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 48199
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 42032
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 8303
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 57565
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 23640
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 85335
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 23056
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 81426
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 8753
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 13942
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 37600
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
#
#  ---------------Number of total disk acceses:  100 ---------------------
# 	---------------- This is Round:  1 -------------------
# 83110
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 79622
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 55251
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 17448
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 71649
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 54885
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 87433
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 65304
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 76961
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 87696
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 92091
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 80573
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 2518
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 83085
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 36257
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 37161
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 2158
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 4532
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 47847
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 91503
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 94003
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 63410
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 64167
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 7327
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 78112
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 31157
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 827
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 25387
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 44018
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 99191
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 71922
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 63358
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 51092
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 38600
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 72908
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 43972
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 27691
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 29632
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 94937
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 72169
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 85310
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 99594
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 9205
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 9938
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 95108
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 98936
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 66774
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 51188
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 90844
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 90488
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 50390
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 42982
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 11838
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 58463
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 23178
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 84040
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 56687
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 20960
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 98982
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 86647
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 70687
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 87578
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 83292
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 98410
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 68191
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 78857
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 50461
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 52894
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 60918
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 56806
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 56295
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 73368
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 19438
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 39543
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 44745
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 21135
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 4586
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 42942
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 58625
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 55853
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 76384
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 11806
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 79331
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 67228
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 82163
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 38565
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 94562
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 16602
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 59927
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 8546
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 65903
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 5749
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 77634
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 22731
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 56272
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 75309
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 50249
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 24928
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 46630
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 41379
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
#
#  ---------------Number of total disk acceses:  100 ---------------------
# 	---------------- This is Round:  2 -------------------
# 27549
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 26304
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 44981
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 56625
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 35956
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 96036
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 61038
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 76023
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 78414
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 44654
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 86861
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 38847
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 8593
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 31728
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 11505
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 39938
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 6485
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 23221
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 8989
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 9192
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 65251
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 27046
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 1248
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 94420
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 77004
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 99059
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 8650
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 13117
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 80143
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 67079
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 57360
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 8272
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 82102
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 76989
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 75744
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 64132
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 69302
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 2456
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 92210
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 44712
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 5605
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 89248
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 28330
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 54306
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 53346
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 50490
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 4324
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 97881
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 29594
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 80520
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 5910
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 76068
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 47350
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 84014
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 29809
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 49309
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 20673
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 59976
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 97459
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 29995
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 41933
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 18612
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 40749
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 94943
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 83812
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 5109
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 88839
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 78621
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 81842
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 10328
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 75594
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 14914
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 89900
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 68122
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 96685
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 9756
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 54978
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 7891
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 14988
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 62122
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 8270
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 2995
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 81738
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 3630
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 98113
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 5302
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 29868
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 69266
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 87711
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 21449
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 37242
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 64163
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 783
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 52551
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 71173
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 89213
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 41081
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 92263
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 74355
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 48114
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
#
#  ---------------Number of total disk acceses:  100 ---------------------
# 	---------------- This is Round:  3 -------------------
# 95872
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 19522
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 4584
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 97676
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 65094
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 34409
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 22946
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 84772
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 3490
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 39727
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 76034
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 37966
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 86207
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 15541
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 79332
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 47697
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 20525
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 14968
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 34501
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 30057
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 29528
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 42928
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 19750
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 29045
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 10813
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 85657
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 94194
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 64443
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 14862
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 51548
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 22230
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 64692
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 27482
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 83959
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 16035
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 9590
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 69944
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 73363
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 36616
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 34039
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 4785
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 39549
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 69009
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 19113
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 62669
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 34305
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 52009
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 20814
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 60545
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 90863
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 63273
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 8674
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 14008
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 88928
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 52010
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 46992
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 75480
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 4131
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 41879
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 99206
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 72467
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 40832
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 49694
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 42680
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 4565
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 57092
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 87369
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 38157
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 39
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 8658
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 95786
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 26618
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 98114
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 16188
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 58610
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 93062
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 92412
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 91773
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 20124
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 29189
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 35676
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 85779
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 2794
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 61625
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 78327
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 37577
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 51895
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 82570
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 16212
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 10833
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 92221
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 84496
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 73800
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 98128
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 89725
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 94297
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 61011
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 98471
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 98502
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 98596
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
#
#  ---------------Number of total disk acceses:  100 ---------------------
# 	---------------- This is Round:  4 -------------------
# 88785
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 7357
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 19847
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 98114
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 43111
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 8916
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 34461
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 15970
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 80845
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 12723
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 90425
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 67592
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 81830
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 91539
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 16974
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 50679
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 91184
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 31861
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 81309
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 96945
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 83167
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 86815
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 48686
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 76364
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 91672
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 24188
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 62743
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 39490
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 53032
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 45453
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 90940
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 44301
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 14982
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 96205
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 82451
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 29821
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 23697
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 60689
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 65384
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 80549
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 80360
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 54209
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 76882
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 80035
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 69087
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 92670
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 49976
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 66069
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 39581
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 15690
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 59918
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 64202
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 23850
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 64741
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 28623
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 17687
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 62436
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 61694
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 11356
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 92862
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 43630
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 48409
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 16073
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 96633
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 93156
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 18742
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 96522
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 58131
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 41245
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 29309
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 61389
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 31754
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 26610
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 51079
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 64887
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 8716
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 39966
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 66959
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 58737
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 20159
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 50537
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 692
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 48648
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 94795
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 8994
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 40916
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 32891
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 56043
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 38158
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 585
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 62562
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 92957
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 95522
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 81315
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 96539
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 56604
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 16227
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 28512
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 6617
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 76869
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
#
#  ---------------Number of total disk acceses:  100 ---------------------
# 	---------------- This is Round:  5 -------------------
# 48311
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 55752
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 16108
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 33260
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 70787
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 89676
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 75408
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 26341
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 36247
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 53034
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 28615
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 18273
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 82150
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 65015
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 66657
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 20155
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 44777
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 6089
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 20415
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 2004
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 3751
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 11133
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 10881
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 70670
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 93691
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 53474
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 37406
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 77228
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 88795
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 41807
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 85806
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 60195
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 18909
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 4204
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 75033
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 76253
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 7479
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 15159
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 43002
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 96262
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 46265
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 98166
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 3464
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 94398
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 78967
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 96168
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 63067
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 6063
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 16129
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 56504
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 73292
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 73323
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 72961
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 64419
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 58276
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 4871
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 55838
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 17386
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 88504
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 58955
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 31965
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 17182
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 40322
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 76808
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 90795
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 23268
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 23198
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 3296
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 47696
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 52483
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 52838
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 21781
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 48793
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 98719
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 9984
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 30962
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 45989
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 60757
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 13339
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 28699
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 67359
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 12903
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 57696
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 71479
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 7695
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 63690
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 76709
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 12688
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 98531
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 68663
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 97189
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 47988
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 80378
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 9499
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 29513
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 77712
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 93853
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 48111
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 57873
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 75593
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
#
#  ---------------Number of total disk acceses:  100 ---------------------
# 	---------------- This is Round:  6 -------------------
# 30294
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 9087
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 80803
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 11484
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 4296
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 9566
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 69736
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 1088
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 63404
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 48495
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 4456
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 12400
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 47130
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 71221
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 89683
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 62753
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 9669
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 34940
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 31219
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 95984
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 67414
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 60620
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 99625
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 94384
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 63721
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 76509
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 54261
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 44972
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 3467
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 48459
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 42511
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 48095
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 30107
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 19918
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 93811
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 58696
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 30656
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 61613
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 89017
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 32207
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 1470
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 70593
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 47610
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 19023
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 72479
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 30105
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 40812
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 57483
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 89614
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 41813
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 39648
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 84589
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 15329
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 25042
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 79434
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 72153
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 40217
#
# ...
# 34183
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 33234
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 41712
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 11842
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 20988
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 5744
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 2176
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 96653
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 70776
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 3175
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 39749
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 74060
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 33373
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 8414
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 76075
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 72255
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 13480
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 26775
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
#
#  ---------------Number of total disk acceses:  99 ---------------------
# 	---------------- This is Round:  8 -------------------
# 47879
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 34823
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 20404
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 36851
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 79760
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 53506
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 28047
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 57435
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 87881
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 53866
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 17658
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 36027
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 41507
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 43732
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 36157
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 78720
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 86025
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 2421
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 8955
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 86107
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 66374
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 78808
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 8690
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 22699
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 11688
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 72698
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 20595
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 4803
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 91383
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 38477
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 94821
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 16821
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 81446
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 13961
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 76249
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 32277
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 56934
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 73869
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 34729
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 6320
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 68589
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 8192
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 2201
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 97882
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 63465
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 49663
#
#  Found
#
#
#
#  The number of disk access used to find the key is 0
# 63818
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 97784
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 21509
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 52954
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 49470
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 90784
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 91760
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 43753
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 90305
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 48095
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 69127
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 94773
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 57463
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 27773
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 65711
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 69694
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 62847
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 84425
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 63921
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 19343
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 44643
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 56859
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 46045
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 28565
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 47992
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 19726
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 96578
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 26939
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 55848
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 62570
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 7471
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 7147
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 99082
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 61250
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 57934
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 57229
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 15346
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 5833
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 84997
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 83458
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 90691
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 96760
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 50215
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 97813
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 67279
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 60905
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 18578
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 54883
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 66797
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 76877
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 49679
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 20637
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 6958
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 69526
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
#
#  ---------------Number of total disk acceses:  99 ---------------------
# 	---------------- This is Round:  9 -------------------
# 37308
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 22560
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 9761
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 84885
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 24442
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 5130
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 78139
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 78681
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 57006
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 71495
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 4443
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 7206
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 42858
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 88340
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 41910
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 68523
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 35766
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 48313
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 14682
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 18090
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 27852
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 45912
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 17804
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 59512
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 33749
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 50779
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 69290
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 60713
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 26866
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 36049
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 82441
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 1376
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 15784
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 38981
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 4527
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 31202
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 90731
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 79417
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 13394
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 61400
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 72197
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 1257
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 711
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 93640
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 30559
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 24308
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 57537
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 9229
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 12751
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 18165
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 91811
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 21116
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 17484
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 15680
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 83554
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 26390
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 18435
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 48213
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 92953
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 31929
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 24855
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 47545
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 47615
#
#  Found
#
#
#
#  The number of disk access used to find the key is 0
# 34695
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 6480
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 34233
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 20340
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 30304
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 35793
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 23558
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 15529
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 69182
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 85910
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 56052
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 4683
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 61551
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 59637
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 68559
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 46359
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 26447
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 36453
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 20282
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 3126
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 21833
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 61394
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 94422
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 99400
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 69115
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 84336
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 97770
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 34191
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 61939
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 31264
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 2487
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 4242
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 54825
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 36139
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 2050
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 44268
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
# 1122
#
#  Found
#
#
#
#  The number of disk access used to find the key is 1
#
#  ---------------Number of total disk acceses:  99 ---------------------
